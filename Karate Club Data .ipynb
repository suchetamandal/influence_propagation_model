# %%
import scipy.io
import pandas as pd
import numpy as np

# %%
import plotly.plotly as py
from plotly.graph_objs import *
import networkx as nx

# %%
low_memory = False;
graph = nx.read_gml('karate.gml',label='id')

# %%
print(graph.number_of_nodes());
print(graph.number_of_edges());
# Out:
# 34
# 78

# %%
import matplotlib.pyplot as plt
nx.draw(graph)
plt.show()

# %%
nodes = graph.number_of_nodes();
edges = graph.number_of_edges();

# %%
degree_dict ={};

# %%
# Calculate degree for graphs and print it
for i in range(1,nodes):
    degree_dict[i] = graph.degree(i);
print(degree_dict);
# Out:
# {1: 16, 2: 9, 3: 10, 4: 6, 5: 3, 6: 4, 7: 4, 8: 4, 9: 5, 10: 2, 11: 3, 12: 1, 13: 2, 14: 5, 15: 2, 16: 2, 17: 2, 18: 2, 19: 2, 20: 3, 21: 2, 22: 2, 23: 2, 24: 5, 25: 3, 26: 3, 27: 2, 28: 4, 29: 3, 30: 4, 31: 4, 32: 6, 33: 12}

# %%
import operator
sorted_degree = sorted(degree_dict.items(), key=lambda x: x[0])
print(sorted_degree);
# Out:
# [(1, 16), (2, 9), (3, 10), (4, 6), (5, 3), (6, 4), (7, 4), (8, 4), (9, 5), (10, 2), (11, 3), (12, 1), (13, 2), (14, 5), (15, 2), (16, 2), (17, 2), (18, 2), (19, 2), (20, 3), (21, 2), (22, 2), (23, 2), (24, 5), (25, 3), (26, 3), (27, 2), (28, 4), (29, 3), (30, 4), (31, 4), (32, 6), (33, 12)]

# %%
mat = nx.adjacency_matrix(graph)

# %%
graph_mat = (mat.todense())

# %%
##Draw Degree Graph
plt.loglog(sorted_degree, 'b-', marker='o')
plt.title("Degree rank plot")
plt.ylabel("degree")
plt.xlabel("rank")

plt.axes([0.45, 0.45, 0.45, 0.45])
Gcc = sorted(nx.connected_component_subgraphs(graph), key=len, reverse=True)[0]
pos = nx.spring_layout(Gcc)
plt.axis('off')
nx.draw_networkx_nodes(Gcc, pos, node_size=20)
nx.draw_networkx_edges(Gcc, pos, alpha=0.4)

plt.show()

# %%
pos = nx.spring_layout(graph, iterations=200)
nx.draw(graph, pos, node_color=range(nodes), node_size=500, cmap=plt.cm.Blues)
plt.show()

# %%
directed = graph.to_undirected();
